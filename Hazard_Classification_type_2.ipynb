# %%
# !cat /proc/uptime | awk '{print $1 /60 /60 /24 "days (" $1 "sec)"}'
# Out:
# 0.0130865days (1130.67sec)

# %%
# !python --version
# Out:
# Python 3.7.11

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
dataFolder = '/content/drive/My Drive/Hazard_code/HazardClassification'
os.chdir(dataFolder)

# %%
# !ls -lia

# %%
# !ls images-agumentor-5k/ | wc -l
# Out:
# ls: cannot open directory 'images-agumentor-100k/': Input/output error
# 0

# %%
# !ls images-agumentor-5k/ | wc -l
# Out:
# ls: cannot open directory 'images-agumentor-100k/': Input/output error
# 0

# %%
# !ls images-agumentor-5k/ | wc -l
# Out:
# ls: cannot open directory 'images-agumentor-100k/': Input/output error
# 0

# %%
# !ls images-agumentor-5k/ | wc -l
# Out:
# ls: cannot open directory 'images-agumentor-100k/': Input/output error
# 0

# %%
# !ls images-agumentor-5k/ | wc -l
# Out:
# ls: cannot open directory 'images-agumentor-100k/': Input/output error
# 0

# %%
# !ls images-agumentor-5k/ | wc -l
# Out:
# 100000

# %%
# !ls images-agumentor-5k/ | wc -l
# Out:
# 100000

# %%
# !ls images-agumentor-5k/ | wc -l
# Out:
# 100000

# %%
# !ls images-agumentor-5k/ | wc -l
# Out:
# 100000

# %%
import tensorflow as tf
print(tf.__version__)
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# 2.5.0
# Found GPU at: /device:GPU:0

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
import subprocess
print(subprocess.getoutput('nvidia-smi'))
# Out:
# Tue Jul 27 12:31:41 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    32W / 250W |    347MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !python train_model_type_2.py --img_path='./images-agumentor-5k' --model_ckpt='model_ckpt_B0_type2_5k.h5' --mapping_file='label_map_type2_5k.pkl' --appEfficientNet=0

# %%
# !python train_model_type_2.py --img_path='./images-agumentor-5k' --model_ckpt='model_ckpt_B1_type2_5k.h5' --mapping_file='label_map_type2_5k.pkl' --appEfficientNet=1

# %%
# !python train_model_type_2.py --img_path='./images-agumentor-5k' --model_ckpt='model_ckpt_B2_type2_5k.h5' --mapping_file='label_map_type2_5k.pkl' --appEfficientNet=2

# %%
# !python train_model_type_2.py --img_path='./images-agumentor-5k' --model_ckpt='model_ckpt_B3_type2_5k.h5' --mapping_file='label_map_type2_5k.pkl' --appEfficientNet=3

# %%
# !python train_model_type_2.py --img_path='./images-agumentor-5k' --model_ckpt='model_ckpt_B4_type2_5k.h5' --mapping_file='label_map_type2_5k.pkl' --appEfficientNet=4

# %%
# !cat /proc/uptime | awk '{print $1 /60 /60 /24 "days (" $1 "sec)"}'
